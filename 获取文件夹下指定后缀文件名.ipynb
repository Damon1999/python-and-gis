# %%
import os
cFileNumber = 0
model_all = ["ACCESS-ESM1","BCC-CSM2-MR","BCC-ESM1","CanESM5","CNRM-CM6-1","EC-Earth3","GISS-E2-1-G",
             "HadGEM3-GC31-MM","IPSL-CM6A-LR","MIROC6","MPI-ESM1-2-HR","MPI-ESM1-2-LR","MRI-ESM2-0","UKESM1-0-LL"]
for model in model_all:
    rootdir = 'G:\\zhutiansheng\\nc\\history\\' + str(model) + "\\"  # 选取删除文件夹的路径,最终结果删除img文件夹 #指定文件夹的路径
    for root, dirs, files in os.walk(rootdir):  # 遍历该文件夹
        for file in files:  # 遍历刚获得的文件名files
            (filename, extension) = os.path.splitext(file)  # 将文件名拆分为文件名与后缀
            if (extension == '.nc'):  # 判断该后缀是否为.c文件
                cFileNumber = cFileNumber + 1  # 记录.c文件的个数为对应文件号
                # print(cFileNumber, os.path.join(root,filename)) #输出文件号以及对应的路径加文件名
                f = open('G:\\zhutiansheng\\nc\\history\\nc2131.txt', 'a')
                f.write(filename + "\n")
                f.close()
                print(filename)  # 以PLACE_RAM(文件名)形式输出文件名
# Out:
# pr_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-201412
# tasmax_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-201412
# tasmin_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-201412
# tas_Amon_BCC-CSM2-MR_historical_r1i1p1f1_gn_185001-201412
# pr_Amon_BCC-ESM1_historical_r1i1p1f1_gn_185001-201412
# tasmax_Amon_BCC-ESM1_historical_r1i1p1f1_gn_185001-201412
# tasmin_Amon_BCC-ESM1_historical_r1i1p1f1_gn_185001-201412
# tas_Amon_BCC-ESM1_historical_r1i1p1f1_gn_185001-201412
# pr_Amon_CanESM5_historical_r1i1p1f1_gn_185001-201412
# tasmax_Amon_CanESM5_historical_r1i1p1f1_gn_185001-201412
# tasmin_Amon_CanESM5_historical_r1i1p1f1_gn_185001-201412
# tas_Amon_CanESM5_historical_r1i1p1f1_gn_185001-201412
# pr_Amon_CNRM-CM6-1_historical_r1i1p1f2_gr_185001-201412
# tasmax_Amon_CNRM-CM6-1_historical_r1i1p1f2_gr_185001-201412
# tasmin_Amon_CNRM-CM6-1_historical_r1i1p1f2_gr_185001-201412
# tas_Amon_CNRM-CM6-1_historical_r1i1p1f2_gr_185001-201412
# ...
