# %%
import arcpy
import re
from netCDF4 import Dataset
import datetime
path_wordspace = "D:\\futrue\\MPI-ESM1-2-HR\\"
path_temp = "D:\\futrue\\MPI-ESM1-2-HR\\temp\\"
D = ".tif"
files = open("D:\\futrue\\nc.txt",'r')
for files_each_line in files:
    #pr_Amon_MRI-ESM2-0_ssp126_r1i1p1f1_gn_201501-201912
    files_each_line = files_each_line.replace('\n', '')
    variable = re.findall(".*?_Amon",files_each_line)
    variable = str(variable).replace("_Amon']",'')
    variable = str(variable).replace("['", '')
    ssp = re.findall("ssp\d\d\d",files_each_line)
    ssp = str(ssp).replace("']", '')
    ssp = str(ssp).replace("['", '')
    files_no_target = path_wordspace + str(variable) + "/" + str(ssp) + "/" + files_each_line + ".nc"
    files_no_temp = path_temp
    files_no_final = path_wordspace
    nc = files_no_target
    nc_obj = Dataset(nc)
    info = nc_obj.variables['time'][:]
    time = info.data
    len1 = len(info)
    for i in range(len1):
        timestamp = -3786825600 + (time[i]) * 3600 * 24
        datetime.datetime(1970, 1, 1) + datetime.timedelta(seconds=timestamp)
        info1 = str(datetime.datetime(1970, 1, 1) + datetime.timedelta(seconds=timestamp))
        change = re.findall("-\d\d ",info1)
        change = str(change).replace("['-","")
        change = str(change).replace("']", "")
        info2 = info1.replace(change,"00" + change)
        info2 = info2.replace("-", "/")
        year = re.findall("\d\d\d\d",info1)
        year = str(year).replace("['", "")
        year = str(year).replace("']", "")
        mon = re.findall("-\d\d\-", info1)
        mon = str(mon).replace("['-", "")
        mon = str(mon).replace("-']", "")
        B = "time " + "'" + info2 + "'"
        print(B)
        try:
            arcpy.MakeNetCDFRasterLayer_md(in_netCDF_file= nc, variable=str(variable),
                                           x_dimension="lon", y_dimension="lat",
                                           out_raster_layer=str(files_each_line) + str(variable) + str(ssp) + str(year) + str(mon),
                                           band_dimension="", dimension_values=B,
                                           value_selection_method="BY_VALUE")
            arcpy.SelectByDimension_md(in_layer_or_table=str(files_each_line) + str(variable) + str(ssp) + str(year) + str(mon),
                                       dimension_values=B,
                                       value_selection_method="BY_VALUE")
        except Exception as e:
            print(e)
        try:
            arcpy.CopyRaster_management(in_raster=str(files_each_line) + str(variable) + str(ssp) + str(year) + str(mon),
                                        out_rasterdataset=files_no_temp + str(variable) + str(ssp) + str(year) + str(mon) + D,
                                        config_keyword="", background_value="",
                                        nodata_value="-3.402823e+038",
                                        onebit_to_eightbit="NONE", colormap_to_RGB="NONE",
                                        pixel_type="",
                                        scale_pixel_value="NONE", RGB_to_Colormap="NONE", format="",
                                        transform="NONE")
            arcpy.Delete_management(str(files_each_line) + str(variable) + str(ssp) + str(year) + str(mon))
        except Exception as e:
            print(e)
        try:
            arcpy.Resample_management(
                in_raster=files_no_temp + str(variable) + str(ssp) + str(year) + str(mon) + D,
                out_raster=files_no_temp + "resample" + str(variable) + str(ssp) + str(year) + str(mon) + D,
                cell_size="0.5 0.5",
                resampling_type="BILINEAR")
            arcpy.Delete_management(files_no_temp + str(variable) + str(ssp) + str(year) + str(mon) + D)
        except Exception as e:
            print(e)
        try:
            arcpy.Clip_management(
                in_raster=files_no_temp + "resample" + str(variable) + str(ssp) + str(year) + str(mon) + D,
                rectangle="95.8334536376953 32.1461541503906 118.096153637695 41.9296541503906",
                out_raster=files_no_final  +
                           str(variable) + "/" + str(ssp) +  "/yelloweriver/mon/" + str(variable) + "-" + str(
                    ssp) + "-" + str(year) + "-" + str(mon) + D,
                in_template_dataset="G:/zhutiansheng/CLIMATE/yellowriver.shp",
                nodata_value="-3.400000e+038", clipping_geometry="ClippingGeometry",
                maintain_clipping_extent="NO_MAINTAIN_EXTENT")
            print('success')
            arcpy.Delete_management(
                files_no_temp + "resample" + str(variable) + str(ssp) + str(year) + str(mon) + D)
        except Exception as e:
            print(e)
# Out:
# time '2050/01/0016 12:00:00'
# success
# time '2050/02/0015 00:00:00'
# success
# time '2050/03/0016 12:00:00'
# success
# time '2050/04/0016 00:00:00'
# success
# time '2050/05/0016 12:00:00'
# success
# time '2050/06/0016 00:00:00'
# success
# time '2050/07/0016 12:00:00'
# success
# time '2050/08/0016 12:00:00'
# success
# time '2050/09/0016 00:00:00'
# success
# time '2050/10/0016 12:00:00'
# success
# time '2050/11/0016 00:00:00'
# success
# time '2050/12/0016 12:00:00'
# success
# time '2051/01/0016 12:00:00'
# success
# time '2051/02/0015 00:00:00'
# success
# time '2051/03/0016 12:00:00'
# success
# time '2051/04/0016 00:00:00'
# success
# time '2051/05/0016 12:00:00'
# success
# time '2051/06/0016 00:00:00'
# success
# time '2051/07/0016 12:00:00'
# success
# time '2051/08/0016 12:00:00'
# success
# time '2051/09/0016 00:00:00'
# success
# time '2051/10/0016 12:00:00'
# success
# time '2051/11/0016 00:00:00'
# success
# time '2051/12/0016 12:00:00'
# success
# time '2052/01/0016 12:00:00'
# success
# time '2052/02/0015 12:00:00'
# success
# time '2052/03/0016 12:00:00'
# success
# time '2052/04/0016 00:00:00'
# success
# time '2052/05/0016 12:00:00'
# success
# time '2052/06/0016 00:00:00'
# success
# time '2052/07/0016 12:00:00'
# success
# time '2052/08/0016 12:00:00'
# success
# time '2052/09/0016 00:00:00'
# success
# time '2052/10/0016 12:00:00'
# success
# time '2052/11/0016 00:00:00'
# success
# time '2052/12/0016 12:00:00'
# success
# time '2053/01/0016 12:00:00'
# success
# time '2053/02/0015 00:00:00'
# success
# time '2053/03/0016 12:00:00'
# success
# time '2053/04/0016 00:00:00'
# success
# time '2053/05/0016 12:00:00'
# success
# time '2053/06/0016 00:00:00'
# success
# time '2053/07/0016 12:00:00'
# success
# time '2053/08/0016 12:00:00'
# success
# time '2053/09/0016 00:00:00'
# success
# time '2053/10/0016 12:00:00'
# success
# time '2053/11/0016 00:00:00'
# success
# time '2053/12/0016 12:00:00'
# success
# time '2054/01/0016 12:00:00'
# success
# time '2054/02/0015 00:00:00'
# success
# time '2054/03/0016 12:00:00'
# success
# time '2054/04/0016 00:00:00'
# success
# time '2054/05/0016 12:00:00'
# success
# time '2054/06/0016 00:00:00'
# success
# time '2054/07/0016 12:00:00'
# success
# time '2054/08/0016 12:00:00'
# success
# time '2054/09/0016 00:00:00'
# success
# time '2054/10/0016 12:00:00'
# success
# time '2054/11/0016 00:00:00'
# success
# time '2054/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
# time '2100/01/0016 12:00:00'
# success
# time '2100/02/0015 00:00:00'
# success
# time '2100/03/0016 12:00:00'
# success
# time '2100/04/0016 00:00:00'
# success
# time '2100/05/0016 12:00:00'
# success
# time '2100/06/0016 00:00:00'
# success
# time '2100/07/0016 12:00:00'
# success
# time '2100/08/0016 12:00:00'
# success
# time '2100/09/0016 00:00:00'
# success
# time '2100/10/0016 12:00:00'
# success
# time '2100/11/0016 00:00:00'
# success
# time '2100/12/0016 12:00:00'
# success
