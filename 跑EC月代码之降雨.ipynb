# %%
import arcpy
import re
path_workspace = "D:/EC-Earth3/"
path_temp = "D:/EC-Earth3/temp/"
files = open("D:/EC-Earth3/nc.txt")
TIF = ".tif" 
NC = ".nc"
for files_no1 in files:
    files_no1 = files_no1.replace("\n", "")
    if len(re.findall("pr", files_no1)) > 0:
        variable = "pr"
    elif len(re.findall("tasmax", files_no1)) > 0:
        variable = "tasmax"
    elif len(re.findall("tasmin", files_no1)) > 0:
        variable = "tasmin"
    elif len(re.findall("tas", files_no1)) > 0:
        variable = "tas"
    ssp1 = re.findall("ssp\d\d\d", files_no1)
    ssp2 = str(ssp1).replace("['", "")
    ssp = str(ssp2).replace("']", "")
    year1 = re.findall("gr_\d\d\d\d", files_no1)
    year2 = str(year1).replace("['gr_", "")
    year = str(year2).replace("']", "")
    for mon in range(1, 13):
        #1,3,5,7,8,10,12 wei0
        if mon in [1,3,5,7,8,10,12]:
            if mon <10:
                B = "time " + "'" + str(year) + "/0" + str(mon) + "/0016" + " 12:00:00'"
            else:
                B = "time " + "'" + str(year) + "/" + str(mon) + "/0016/" + " 12:00:00'"
        #2,4,6,9,11
        else:
            if mon > 10:
                B = "time " + "'" + str(year) + "/" + str(mon) + "/0016" + " 0:00:00'"
            else:
                if mon ==2:
                    B = "time " + "'" + str(year) + "/0" + str(mon) + "/0015" + " 0:00:00'"
                else:
                    B = "time " + "'" + str(year) + "/0" + str(mon) + "/0016" + " 0:00:00'"
        print(B)
        out_raster_layer = str(files_no1) + str(year) + str(mon)
        NC_input = path_workspace + str(variable) + "/" + str(ssp) + "/" + files_no1 + ".nc"
        print(NC_input)
        out_raster_layer = str(files_no1) + str(year) + str(mon)
        arcpy.MakeNetCDFRasterLayer_md(
                in_netCDF_file=NC_input,
                variable=str(variable), x_dimension="lon", y_dimension="lat",
                out_raster_layer=str(files_no1) + str(year) + str(mon), band_dimension="", dimension_values=B,
                value_selection_method="BY_VALUE")
        arcpy.SelectByDimension_md(in_layer_or_table=str(files_no1) + str(year) + str(mon),
                                       dimension_values=B,
                                       value_selection_method="BY_VALUE")
        try:
            arcpy.CopyRaster_management(in_raster=str(files_no1) + str(year) + str(mon),
                                        out_rasterdataset=path_temp + str(variable) + str(
                                            year) + str(mon) + TIF,
                                        config_keyword="", background_value="",
                                        nodata_value="-3.402823e+038",
                                        onebit_to_eightbit="NONE", colormap_to_RGB="NONE",
                                        pixel_type="",
                                        scale_pixel_value="NONE", RGB_to_Colormap="NONE", format="",
                                        transform="NONE")
            print('copy_finish')
        except Exception as e:
            print(e)
        try:
            arcpy.Resample_management(
                in_raster=path_temp + str(variable) + str(year) + str(mon) + TIF,
                out_raster=path_temp + "resample" + str(variable) + str(year) + str(
                    mon) + TIF,
                cell_size="0.5 0.5",
                resampling_type="BILINEAR")
            print('resample_finish')
            arcpy.Delete_management(path_temp + str(variable) + str(year) + str(mon) + TIF)
        except Exception as e:
            print(e)
        try:
            arcpy.Clip_management(
                in_raster=path_temp + "resample" + str(variable) + str(year) + str(
                    mon) + TIF,
                rectangle="95.8334536376953 32.1461541503906 118.096153637695 41.9296541503906",
                out_raster=path_workspace +
                           str(variable) + "/" + str(ssp) + "/tif/yellowriver/mon/" + str(
                    variable) + "-" + str(year) + "-" + str(mon) + TIF,
                in_template_dataset="G:/zhutiansheng/CLIMATE/yellowriver.shp",
                nodata_value="-3.400000e+038", clipping_geometry="ClippingGeometry",
                maintain_clipping_extent="NO_MAINTAIN_EXTENT")
            print('success')
        except Exception as e:
            print(e)
        arcpy.Delete_management(path_temp + "resample" + str(variable) + str(year) + str(mon) + TIF)
# Out:
# time '2015/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2015/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201501-201512.nc
# copy_finish
# resample_finish
# success
# time '2016/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2016/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201601-201612.nc
# copy_finish
# resample_finish
# success
# time '2017/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2017/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201701-201712.nc
# copy_finish
# resample_finish
# success
# time '2018/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2018/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201801-201812.nc
# copy_finish
# resample_finish
# success
# time '2019/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2019/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_201901-201912.nc
# copy_finish
# resample_finish
# success
# time '2020/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2020/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202001-202012.nc
# copy_finish
# resample_finish
# success
# time '2021/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2021/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202101-202112.nc
# copy_finish
# resample_finish
# success
# time '2022/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2022/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202201-202212.nc
# copy_finish
# resample_finish
# success
# time '2023/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2023/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202301-202312.nc
# copy_finish
# resample_finish
# success
# time '2024/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2024/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202401-202412.nc
# copy_finish
# resample_finish
# success
# time '2025/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2025/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202501-202512.nc
# copy_finish
# resample_finish
# success
# time '2026/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2026/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202601-202612.nc
# copy_finish
# resample_finish
# success
# time '2027/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2027/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202701-202712.nc
# copy_finish
# resample_finish
# success
# time '2028/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2028/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202801-202812.nc
# copy_finish
# resample_finish
# success
# time '2029/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2029/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_202901-202912.nc
# copy_finish
# resample_finish
# success
# time '2030/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2030/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203001-203012.nc
# copy_finish
# resample_finish
# success
# time '2031/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2031/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203101-203112.nc
# copy_finish
# resample_finish
# success
# time '2032/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2032/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203201-203212.nc
# copy_finish
# resample_finish
# success
# time '2033/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2033/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203301-203312.nc
# copy_finish
# resample_finish
# success
# time '2034/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2034/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203401-203412.nc
# copy_finish
# resample_finish
# success
# time '2035/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2035/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203501-203512.nc
# copy_finish
# resample_finish
# success
# time '2036/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2036/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203601-203612.nc
# copy_finish
# resample_finish
# success
# time '2037/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2037/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203701-203712.nc
# copy_finish
# resample_finish
# success
# time '2038/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2038/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203801-203812.nc
# copy_finish
# resample_finish
# success
# time '2039/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2039/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_203901-203912.nc
# copy_finish
# resample_finish
# success
# time '2040/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2040/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204001-204012.nc
# copy_finish
# resample_finish
# success
# time '2041/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2041/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204101-204112.nc
# copy_finish
# resample_finish
# success
# time '2042/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/03/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/04/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/05/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/06/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/07/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/08/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/09/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/10/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/11/0016 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2042/12/0016/ 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204201-204212.nc
# copy_finish
# resample_finish
# success
# time '2043/01/0016 12:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204301-204312.nc
# copy_finish
# resample_finish
# success
# time '2043/02/0015 0:00:00'
# D:/EC-Earth3/pr/ssp126/pr_Amon_EC-Earth3_ssp126_r1i1p1f1_gr_204301-204312.nc
# copy_finish
# resample_finish
# success
# time '2043/03/0016 12:00:00'
# ...
# 执行(Clip)失败。
#
# time '2059/08/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_205901-205912.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2059-8.tif 已存在。
# 执行(Clip)失败。
#
# time '2059/09/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_205901-205912.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2059-9.tif 已存在。
# 执行(Clip)失败。
#
# time '2059/10/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_205901-205912.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2059-10.tif 已存在。
# 执行(Clip)失败。
#
# time '2059/11/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_205901-205912.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2059-11.tif 已存在。
# 执行(Clip)失败。
#
# time '2059/12/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_205901-205912.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2059-12.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/01/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-1.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/02/0015 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-2.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/03/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-3.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/04/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-4.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/05/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-5.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/06/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-6.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/07/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-7.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/08/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-8.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/09/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-9.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/10/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-10.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/11/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-11.tif 已存在。
# 执行(Clip)失败。
#
# time '2060/12/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206001-206012.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2060-12.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/01/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-1.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/02/0015 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-2.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/03/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-3.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/04/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-4.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/05/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-5.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/06/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-6.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/07/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-7.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/08/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-8.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/09/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-9.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/10/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-10.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/11/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-11.tif 已存在。
# 执行(Clip)失败。
#
# time '2061/12/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206101-206112.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2061-12.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/01/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-1.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/02/0015 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-2.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/03/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-3.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/04/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-4.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/05/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-5.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/06/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-6.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/07/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-7.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/08/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-8.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/09/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-9.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/10/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-10.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/11/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-11.tif 已存在。
# 执行(Clip)失败。
#
# time '2062/12/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206201-206212.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2062-12.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/01/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-1.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/02/0015 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-2.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/03/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-3.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/04/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-4.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/05/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-5.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/06/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-6.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/07/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-7.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/08/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-8.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/09/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-9.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/10/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-10.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/11/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-11.tif 已存在。
# 执行(Clip)失败。
#
# time '2063/12/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206301-206312.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2063-12.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/01/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-1.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/02/0015 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-2.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/03/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-3.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/04/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-4.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/05/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-5.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/06/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-6.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/07/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-7.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/08/0016 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-8.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/09/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-9.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/10/0016/ 12:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
# 执行失败。参数无效。
# ERROR 000725: 输出栅格数据集: 数据集 D:\EC-Earth3\tas\ssp370\tif\yellowriver\mon\tas-2064-10.tif 已存在。
# 执行(Clip)失败。
#
# time '2064/11/0016 0:00:00'
# D:/EC-Earth3/tas/ssp370/tas_Amon_EC-Earth3_ssp370_r1i1p1f1_gr_206401-206412.nc
# copy_finish
# resample_finish
